# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualize import LossVisualizer
from src.utils import init_dataloader
from src.utils import create_losses_func
from src.models.mlp import MLP
from src.train import train

import numpy as np

from torchvision import transforms

import torch
import torch.nn as nn


DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
transform = transforms.Compose([transforms.ToTensor(),
                               transforms.Normalize((0.5,), (0.5,))])

loader = init_dataloader(
    dataset_name='MNIST',
    transform=transform,
    batch_size=64,
    dataset_load_path='data/',
    train_mode=True,
    size = 64*(10000//64)
)

model = MLP([784, 128, 128, 128, 10]).to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr = 3e-4)
criterion = nn.CrossEntropyLoss()

model, losses = train(
    model,
    optimizer,
    criterion,
    loader,
    20,
    DEVICE
)
# Out:
# Train loop:   0%|          | 0/20 [00:00<?, ?it/s]

# %%
losses_func = create_losses_func(loader, criterion)
vis = LossVisualizer(visual_type='random_2', grid_step=0.1, direction_norm=10)
vis.initialize_grid_loss(model, losses_func)
# Out:
# 0it [00:00, ?it/s]

# %%
vis.visualize(size = 1)
vis.visualize(size = 4)
vis.visualize(size = 16)
vis.visualize(size = -1)

# %%
vis.visualize_diff(size1 = 2, size2 = -1, diff_type='square')
vis.visualize_diff(size1 = 2, size2 = -1, diff_type='abs')
vis.visualize_diff(size1 = 2, size2 = -1, diff_type='relative_square')
vis.visualize_diff(size1 = 2, size2 = -1, diff_type='relative_abs')
vis.visualize_diff(size1 = 2, size2 = -1, diff_type=None)

# %%
vis.visualize_diff(size1 = 4, size2 = 5, diff_type='square')
vis.visualize_diff(size1 = 4, size2 = 5, diff_type='abs')
vis.visualize_diff(size1 = 4, size2 = 5, diff_type='relative_square')
vis.visualize_diff(size1 = 4, size2 = 5, diff_type='relative_abs')
vis.visualize_diff(size1 = 4, size2 = 5, diff_type=None)

# %%
vis.visualize_diff(size1 = 1, size2 = 2, diff_type='abs')
vis.visualize_diff(size1 = 4, size2 = 5, diff_type='abs')
vis.visualize_diff(size1 = 16, size2 = 17, diff_type='abs')
vis.visualize_diff(size1 = 1, size2 = -1, diff_type='abs')

# %%
vis.visualize_diff(size1 = 1, size2 = 2, diff_type='square')
vis.visualize_diff(size1 = 4, size2 = 5, diff_type='square')
vis.visualize_diff(size1 = 16, size2 = 17, diff_type='square')
vis.visualize_diff(size1 = 1, size2 = -1, diff_type='square')

# %%
vis.visualize_diff(size1 = 1, size2 = 2, diff_type='relative_square')
vis.visualize_diff(size1 = 4, size2 = 5, diff_type='relative_square')
vis.visualize_diff(size1 = 16, size2 = 17, diff_type='relative_square')
vis.visualize_diff(size1 = 64, size2 = 65, diff_type='relative_square')
vis.visualize_diff(size1 = 1, size2 = -1, diff_type='relative_square')

# %%
vis.visualize_diff(size1 = 1, size2 = -1,
                   diff_type='square_dot_normal',
                   distrib_params = {'loc':[0, 0], 'scale':[0.1, 0.1]})
vis.visualize_diff(size1 = 1, size2 = -1,
                   diff_type='square_dot_normal',
                   distrib_params = {'loc':[0, 0], 'scale':[0.3, 0.3]})
vis.visualize_diff(size1 = 1, size2 = -1,
                   diff_type='square_dot_normal',
                   distrib_params = {'loc':[0, 0], 'scale':[0.5, 0.5]})
vis.visualize_diff(size1 = 1, size2 = -1,
                   diff_type='square_dot_normal',
                   distrib_params = {'loc':[0, 0], 'scale':[1, 1]})
vis.visualize_diff(size1 = 1, size2 = -1,
                   diff_type='square_dot_normal',
                   distrib_params = {'loc':[0, 0], 'scale':[10, 10]})

# %%
vis.visualize_diff(size1 = 1, size2 = 2,
                   diff_type='square_dot_normal',
                   distrib_params = {'loc':[0, 0], 'scale':[0.5, 0.5]})
vis.visualize_diff(size1 = 5, size2 = 6,
                   diff_type='square_dot_normal',
                   distrib_params = {'loc':[0, 0], 'scale':[0.5, 0.5]})
vis.visualize_diff(size1 = 16, size2 = 17,
                   diff_type='square_dot_normal',
                   distrib_params = {'loc':[0, 0], 'scale':[0.5, 0.5]})
vis.visualize_diff(size1 = 2, size2 = -1,
                   diff_type='square_dot_normal',
                   distrib_params = {'loc':[0, 0], 'scale':[0.5, 0.5]})
